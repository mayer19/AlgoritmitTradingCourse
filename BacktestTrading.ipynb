# %%
#imports
import pandas as pd
import pandas_ta as ta

# %%
#import data from excel into a pandas DF
adidas = pd.read_csv('ADS.DE.csv')
bnp = pd.read_csv('BNP.PA.csv')
galp = pd.read_csv('GALP.LS.csv')
ko = pd.read_csv('KO.csv')
nos = pd.read_csv('NOS.LS.csv')
pepsico = pd.read_csv('PEP.csv')
paypal = pd.read_csv('PYPL.csv')
renault = pd.read_csv('RNO.PA.csv')
sap = pd.read_csv('SAP.DE.csv')
tesla = pd.read_csv('TSLA.csv')
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3444  2024-03-06  179.990005  181.580002  173.699997  176.539993  176.539993
# 3445  2024-03-07  174.350006  180.039993  173.699997  178.649994  178.649994
# 3446  2024-03-08  181.500000  182.729996  174.699997  175.339996  175.339996
# 3447  2024-03-11  175.449997  182.869995  174.800003  177.770004  177.770004
# 3448  2024-03-12  177.770004  179.429993  172.410004  177.539993  177.539993
#
#          Volume
# 0     281494500
# ...

# %%
#calculate indicators using pandas_ta

def calculate_indis(data):
    """Use a asset pandas dataframe and calculate indicators"""
    data['ema20'] = ta.ema(data['Close'], length=20)
    data['ema25'] = ta.ema(data['Close'], length=25)
    data['ema35'] = ta.ema(data['Close'], length=35)
    data['ema60'] = ta.ema(data['Close'], length=60)
    #data['%K'], data['%D'] = ta.stoch(data['High'], data['Low'], data['Close']) #default parameters
    data['coppock'] = ta.coppock(data['Close'], length=14)
    data['CMO'] = ta.cmo(data['Close'], length=14)
    data['rsx'] = ta.rsx(adidas['Close'], length=14) #0 to 100
    data['fisher1'],  = ta.fisher(data['High'], data['Low'])
    return data


tesla = calculate_indis(tesla)
tesla.head(30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [28], line 17
#      13     data['fisher'] = ta.fisher(data['High'], data['Low'])
#      14     return data
# ---> 17 tesla = calculate_indis(tesla)
#      18 tesla.head(30)
#
# Cell In [28], line 13, in calculate_indis(data)
#      11 data['CMO'] = ta.cmo(data['Close'], length=14)
#      12 data['rsx'] = ta.rsx(adidas['Close'], length=14) #0 to 100
# ---> 13 data['fisher'] = ta.fisher(data['High'], data['Low'])
#      14 return data
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4081, in DataFrame.__setitem__(self, key, value)
#    4079     self._setitem_array(key, value)
#    4080 elif isinstance(value, DataFrame):
# -> 4081     self._set_item_frame_value(key, value)
#    4082 elif (
#    4083     is_list_like(value)
# ...

# %%
# Calculate True Strength Index (TSI) with default parameters
vi_plus = ta.rsx(adidas['Close'], length=14)
adidas['a'] = vi_plus
adidas
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1998-06-24   40.916248   41.159000   40.775501   40.775501   28.876129
# 1     1998-06-25   41.146252   41.286751   40.622250   40.647751   28.785662
# 2     1998-06-26   40.647751   40.673248   39.880749   39.925499   28.274183
# 3     1998-06-29   40.136501   40.520000   40.136501   40.424000   28.627197
# 4     1998-06-30   40.634998   40.634998   39.433498   39.631500   28.065983
# ...          ...         ...         ...         ...         ...         ...
# 6581  2024-03-06  184.699997  193.720001  182.279999  185.960007  185.960007
# 6582  2024-03-07  184.399994  188.500000  180.820007  188.399994  188.399994
# 6583  2024-03-08  189.179993  191.520004  187.960007  189.139999  189.139999
# 6584  2024-03-11  188.240005  188.860001  185.679993  188.860001  188.860001
# 6585  2024-03-12  190.660004  192.960007  189.899994  192.740005  192.740005
#
#       Volume          a             b
# ...

# %%
tesla.ta.indicators()
# Out:
# Pandas TA - Technical Analysis Indicators - v0.3.14b0
# Total Indicators & Utilities: 205
# Abbreviations:
# ...
